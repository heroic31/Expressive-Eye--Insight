# %%
import cv2

# %%
import matplotlib.pyplot as plt

# %%
from deepface import DeepFace

# %%
img=cv2.imread('happyboy.jpg')
plt.imshow(img)

# %% [markdown]
# ##### bgr changing

# %%
plt.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))

# %%
predictiions=DeepFace.analyze(img)
# Out:
# Action: race: 100%|██████████████████████████████████████████████████████████████████████| 4/4 [00:07<00:00,  1.97s/it]

# %%
predictiions
# Out:
# [{'emotion': {'angry': 5.7877411630685716e-11,
#    'disgust': 3.5859766626391773e-13,
#    'fear': 3.2271383343385196e-07,
#    'happy': 100.0,
#    'sad': 1.110978713539379e-10,
#    'surprise': 1.9946019662320236e-10,
#    'neutral': 2.1901740865359898e-06},
#   'dominant_emotion': 'happy',
#   'region': {'x': 255, 'y': 254, 'w': 474, 'h': 474},
#   'age': 31,
#   'gender': {'Woman': 0.7548652123659849, 'Man': 99.24513697624207},
#   'dominant_gender': 'Man',
#   'race': {'asian': 1.9312272999422133,
#    'indian': 1.9096232226266399,
#    'black': 0.10570110219053043,
#    'white': 55.29795022594632,
#    'middle eastern': 21.66164795527744,
#    'latino hispanic': 19.093855863443366},
#   'dominant_race': 'white'}]

# %%
type(predictiions)
# Out:
# list

# %%
for item in predictiions:
    dominant_emotion = item['dominant_emotion']
    print(dominant_emotion)
# Out:
# happy

# %% [markdown]
# ##### we are trying to draw rectangle around face

# %%
faceCascade=cv2.CascadeClassifier(cv2.data.haarcascades + 'haarcascade_frontalface_default.xml')

# %%
gray=cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)

faces=faceCascade.detectMultiScale(gray,1.1,4)
for(x,y,w,h) in faces:
    cv2.rectangle(img,(x,y),(x+w,y+h),(0,255,0),2)

# %%
plt.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))

# %%
  cv2.putText(img, dominant_emotion, (50, 50), cv2.FONT_HERSHEY_SIMPLEX, 1.0, (0, 255, 0), 2,cv2.LINE_4)
# Out:
# array([[[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        ...,
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
# ...

# %%
plt.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))

# %%
img2=cv2.imread('sadboy.jpg')
print(img.dtype)
# Out:
# uint8

# %%
plt.imshow(img2)

# %%
predictions2=DeepFace.analyze(img2)
# Out:
# Action: race: 100%|██████████████████████████████████████████████████████████████████████| 4/4 [00:01<00:00,  2.05it/s]

# %%
predictions2
# Out:
# [{'emotion': {'angry': 34.9164652923983,
#    'disgust': 0.01125640858354019,
#    'fear': 12.007965951208359,
#    'happy': 0.0022191431609212193,
#    'sad': 52.75275078383079,
#    'surprise': 0.01628805572644702,
#    'neutral': 0.29305223141733033},
#   'dominant_emotion': 'sad',
#   'region': {'x': 74, 'y': 110, 'w': 326, 'h': 326},
#   'age': 29,
#   'gender': {'Woman': 9.14456695318222, 'Man': 90.85543751716614},
#   'dominant_gender': 'Man',
#   'race': {'asian': 2.898304723203182,
#    'indian': 0.5741962231695652,
#    'black': 0.09180859779007733,
#    'white': 60.3520929813385,
#    'middle eastern': 6.775343418121338,
#    'latino hispanic': 29.308250546455383},
#   'dominant_race': 'white'}]

# %%
type(predictions2)
# Out:
# list

# %%
for item in predictions2:
    dominant_emotion = item['dominant_emotion']
    print(dominant_emotion)
# Out:
# sad

# %%
faceCascade=cv2.CascadeClassifier(cv2.data.haarcascades + 'haarcascade_frontalface_default.xml')

# %%
gray=cv2.cvtColor(img2,cv2.COLOR_BGR2GRAY)
#print(faceCascade.empty())
faces=faceCascade.detectMultiScale(gray,1.1,4)
for(x,y,w,h) in faces:
    cv2.rectangle(img2,(x,y),(x+w,y+h),(0,255,0),2)

# %%
plt.imshow(cv2.cvtColor(img2, cv2.COLOR_BGR2RGB))

# %%
   cv2.putText(img2, dominant_emotion, (50, 50), cv2.FONT_HERSHEY_SIMPLEX, 1.0, (0, 255, 0), 2,cv2.LINE_4)
# Out:
# array([[[112, 112, 112],
#         [112, 112, 112],
#         [112, 112, 112],
#         ...,
#         [100, 100, 100],
#         [ 99,  99,  99],
#         [ 99,  99,  99]],
#
#        [[112, 112, 112],
#         [112, 112, 112],
#         [112, 112, 112],
#         ...,
#         [ 98,  98,  98],
#         [ 98,  98,  98],
#         [ 98,  98,  98]],
#
#        [[112, 112, 112],
#         [112, 112, 112],
#         [113, 113, 113],
#         ...,
#         [ 98,  98,  98],
#         [ 98,  98,  98],
#         [ 99,  99,  99]],
#
#        ...,
#
#        [[ 34,  34,  34],
#         [ 32,  32,  32],
#         [ 26,  26,  26],
#         ...,
#         [  4,   4,   4],
#         [  4,   4,   4],
#         [  5,   5,   5]],
#
#        [[ 29,  29,  29],
#         [ 27,  27,  27],
#         [ 22,  22,  22],
#         ...,
#         [  2,   2,   2],
#         [  3,   3,   3],
#         [  5,   5,   5]],
#
#        [[ 25,  25,  25],
#         [ 25,  25,  25],
#         [ 28,  28,  28],
# ...

# %%
plt.imshow(cv2.cvtColor(img2, cv2.COLOR_BGR2RGB))

# %%
img3=cv2.imread('fearmen.jpeg')
print(img3.dtype)
# Out:
# uint8

# %%
plt.imshow(img3)

# %%
plt.imshow(cv2.cvtColor(img3, cv2.COLOR_BGR2RGB))

# %%
predictions3=DeepFace.analyze(img3)
# Out:
# Action: race: 100%|██████████████████████████████████████████████████████████████████████| 4/4 [00:01<00:00,  2.01it/s]

# %%
predictions3
# Out:
# [{'emotion': {'angry': 0.5997418675263962,
#    'disgust': 1.9137982015721334e-05,
#    'fear': 99.22574749299854,
#    'happy': 0.028105231907656122,
#    'sad': 6.863648104292301e-05,
#    'surprise': 0.14632029340509098,
#    'neutral': 3.9100402927509707e-10},
#   'dominant_emotion': 'fear',
#   'region': {'x': 372, 'y': 54, 'w': 859, 'h': 859},
#   'age': 30,
#   'gender': {'Woman': 0.011408082355046645, 'Man': 99.98859167098999},
#   'dominant_gender': 'Man',
#   'race': {'asian': 5.907388776540756,
#    'indian': 10.890502482652664,
#    'black': 6.472046673297882,
#    'white': 26.073938608169556,
#    'middle eastern': 21.264353394508362,
#    'latino hispanic': 29.39176857471466},
#   'dominant_race': 'latino hispanic'}]

# %%
type(predictions3)
# Out:
# list

# %%
for item in predictions3:
    dominant_emotion = item['dominant_emotion']
    print(dominant_emotion)
# Out:
# fear

# %%
faceCascade=cv2.CascadeClassifier(cv2.data.haarcascades + 'haarcascade_frontalface_default.xml')

# %%
gray=cv2.cvtColor(img3,cv2.COLOR_BGR2GRAY)
#print(faceCascade.empty())
faces=faceCascade.detectMultiScale(gray,1.1,4)
for(x,y,w,h) in faces:
    cv2.rectangle(img3,(x,y),(x+w,y+h),(0,255,0),2)

# %%
cv2.putText(img3, dominant_emotion, (50, 50), cv2.FONT_HERSHEY_SIMPLEX, 1.0, (0, 255, 0), 2,cv2.LINE_4)
# Out:
# array([[[254, 252, 252],
#         [254, 252, 252],
#         [254, 252, 252],
#         ...,
#         [254, 252, 252],
#         [254, 252, 252],
#         [254, 252, 252]],
#
#        [[254, 252, 252],
#         [254, 252, 252],
#         [254, 252, 252],
#         ...,
#         [254, 252, 252],
#         [254, 252, 252],
#         [254, 252, 252]],
#
#        [[254, 252, 252],
#         [254, 252, 252],
#         [254, 252, 252],
#         ...,
#         [254, 252, 252],
#         [254, 252, 252],
#         [254, 252, 252]],
#
#        ...,
#
#        [[254, 252, 252],
#         [254, 252, 252],
#         [254, 252, 252],
#         ...,
#         [254, 252, 252],
#         [254, 252, 252],
#         [254, 252, 252]],
#
#        [[254, 252, 252],
#         [254, 252, 252],
#         [254, 252, 252],
#         ...,
#         [254, 252, 252],
#         [254, 252, 252],
#         [254, 252, 252]],
#
#        [[254, 252, 252],
#         [254, 252, 252],
#         [254, 252, 252],
# ...

# %%
plt.imshow(cv2.cvtColor(img3, cv2.COLOR_BGR2RGB))

# %%
img4=cv2.imread('angry.jpg')
print(img4.dtype)
plt.imshow
# Out:
# uint8
# <function matplotlib.pyplot.imshow(X, cmap=None, norm=None, *, aspect=None, interpolation=None, alpha=None, vmin=None, vmax=None, origin=None, extent=None, interpolation_stage=None, filternorm=True, filterrad=4.0, resample=None, url=None, data=None, **kwargs)>

# %%
import cv2
from deepface import DeepFace


faceCascade = cv2.CascadeClassifier(cv2.data.haarcascades + 'haarcascade_frontalface_default.xml')


cap = cv2.VideoCapture(1)
if not cap.isOpened():
    cap = cv2.VideoCapture(0)
    if not cap.isOpened():
        raise IOError("Cannot Open Webcam")

cap.set(cv2.CAP_PROP_FRAME_WIDTH, 640)
cap.set(cv2.CAP_PROP_FRAME_HEIGHT, 480)

while True:
    
    ret, frame = cap.read()

    result = DeepFace.analyze(frame, actions=['emotion'], enforce_detection=False)

   
    gray = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)

   
    faces = faceCascade.detectMultiScale(gray, scaleFactor=1.1, minNeighbors=5, minSize=(30, 30))

    for (x, y, w, h) in faces:
        cv2.rectangle(frame, (x, y), (x+w, y+h), (0, 255, 0), 2)
        
        
        dominant_emotion = result[0]['dominant_emotion']
        

        cv2.putText(frame, dominant_emotion, (x, y - 10), cv2.FONT_HERSHEY_SIMPLEX, 0.9, (0, 255, 0), 2, cv2.LINE_4)

   
    cv2.imshow('Original Video', frame)

   
    if cv2.waitKey(1) & 0xFF == ord('q'):
        break

cap.release()
cv2.destroyAllWindows()
# Out:
# ...
# Finding actions:   0%|                                                                           | 0/1 [00:00<?, ?it/s]
